# %% [markdown]
# <a href="https://colab.research.google.com/github/aasjunior/UdemyEstruturaDados_Python/blob/main/03_vetores/Vetores_nao_ordenados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Vetores não ordenados

# %% [markdown]
# #### Inserção
#
#
# *   Único passo (inserido na primeira célula vaga do vetor)
# *   O algoritmo já conhece essa localização porque ele já sabe quantos itens já estão no vetor
# *   O novo item é simplesmente inserido no próximo espaço disponível
# *   Big-O: constante - O(1)

# %% [markdown]
# #### Pesquisa Linear
#
#
# *   Percorre cada posição do vetor até localizar o elemento
# *   Big-O linear: O(n)

# %% [markdown]
# #### Exclusão
#
#
# *   Pesquisar uma média de N/2 elemtentos (pesquisa linear)
#   *   Pior caso: N
#
#
# *   Mover os elementos restantes (N/2 passos)
#   *   Pior caso: N
#
#
# *   Big-O: O(2n) = O(n)

# %% [markdown]
# ### Duplicatas
#
#
# *   Deve-se decidir se itens com chaves duplicadas serão permitidos
# *   Pesquisa: mesmo se encontrar o valor, o algoritmo terá que continuar procurando até a última célula (N passos)
# *   Inserção: verificar cada item antes de fazer uma inserção (N passos)
# *   Exclusão do primeiro item: N/2 comparações e N/2 movimentos
# *   Exclusão de mais itens: verificar N células e mais de N/2 células

# %% [markdown]
# ## Implementação

# %%
import numpy as np

# %%
class VetorNaoOrdenado:
  def __init__(self, capacidade):
    self.capacidade = capacidade

    # ponteiro
    self.ultima_posicao = -1
    self.valores = np.empty(self.capacidade, dtype=int)

  # O(n)
  def imprime(self):
    if self.ultima_posicao == -1:
      print('O vetor está vazio')
    else:
      for i in range(self.ultima_posicao + 1):
        print(i, ' - ', self.valores[i])

  # O(1)
  def insere(self, valor):
    if self.ultima_posicao == self.capacidade -1:
      print('capacidade máxima atingida')
    else:
      self.ultima_posicao += 1
      self.valores[self.ultima_posicao] = valor

  # O(n)
  def pesquisar(self, valor):
    for i in range(self.ultima_posicao + 1):
      if valor == self.valores[i]:
        return i
    return -1

  # O(n)
  def excluir(self, valor):
    posicao = self.pesquisar(valor)
    if posicao == -1:
      return -1
    else:
      for i in range(posicao, self.ultima_posicao):
        self.valores[i] = self.valores[i+1]
      self.ultima_posicao -= 1

# %%
vetor = VetorNaoOrdenado(5)

# %%
vetor.imprime()
# Out:
# O vetor está vazio

# %%
vetor.insere(2)

# %%
vetor.imprime()
# Out:
# 0  -  2

# %%
vetor.insere(3)
vetor.insere(5)
vetor.insere(8)
vetor.insere(1)

# %%
vetor.imprime()
# Out:
# 0  -  2
# 1  -  3
# 2  -  5
# 3  -  8
# 4  -  1

# %%
vetor.insere(7)
# Out:
# capacidade máxima atingida

# %%
vetor.ultima_posicao
# Out:
# 4

# %%
vetor.pesquisar(8)
# Out:
# 3

# %%
# Pior caso: percorreu todo o array e não encontrou o valor
vetor.pesquisar(9)
# Out:
# -1

# %%
# Melhor caso: número pesquisado está na primeira posição
vetor.pesquisar(2)
# Out:
# 0

# %%
# teste excluir elemento do meio
vetor.excluir(5)
vetor.imprime()
# Out:
# 0  -  2
# 1  -  3
# 2  -  8
# 3  -  1

# %%
# teste excluir elemento do final
vetor.excluir(1)
vetor.imprime()
# Out:
# 0  -  2
# 1  -  3
# 2  -  8

# %%
# teste excluir elemento do inicio
vetor.excluir(2)
vetor.imprime()
# Out:
# 0  -  3
# 1  -  8

# %%
vetor.insere(5)
vetor.insere(1)
vetor.imprime()
# Out:
# 0  -  3
# 1  -  8
# 2  -  5
# 3  -  1

# %% [markdown]
# ### Debug passo a passo (PyCharm)
#
#
# 1.   Selecionr a linha
# 2.   `Ctrl` + `F8` ou Run -> Toggle Breakpoint -> Line Breakpoint

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   `Shift` + `F9` ou Run -> Debug 'main'
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   Step Over (F8): Executa a linha de codigo
# *   Step Into (F7): Visualiza as linhas executadas
#
# ![image.png](data:image/png;base64,...)
